# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
scores = pd.read_csv('Encoder_Model_ALL.csv')
plotted_scores = scores[['encoder_layer', 'val_score', 'train_score']]

x = plotted_scores['encoder_layer']
plt.plot(x, plotted_scores['train_score'], label="Exactitude (apprentissage)")
plt.plot(x, plotted_scores['val_score'], label="Exactitude (test)")

ax = plt.gca()
ax.set_xticks(x)
plt.xlabel("Indice de la couche d'encodage")
plt.ylabel("Exactitude")

plt.legend()
plt.tight_layout()
plt.savefig('accuracy_dataset_classif.png')

# %%
scores
# Out:
#    Unnamed: 0  encoder_layer  val_score  train_score
# 0           0              0   0.576322     0.613419
# 1           1              1   0.807148     0.849521
# 2           2              2   0.956813     0.955272
# 3           3              3   0.973939     0.973163
# 4           4              4   0.942666     0.946326

# %%
import numpy as np

prob_result = np.load('probing_result.pkl.npy', allow_pickle=True).item()

# %%
r = {d:(v[0].item(), v[1][i].numpy()) for i, (d, v) in enumerate(prob_result.items())}
r
# Out:
# {'IDRID': (0.8250186443328857, array([1108,    4,   26,  205,    0])),
#  'MESSIDOR': (0.6515264511108398, array([ 43, 875, 137, 288,   0])),
#  'DDR': (0.7505584359169006, array([  62,    2, 1008,  271,    0])),
#  'FGADR': (0.7930007576942444, array([  13,    2,  188, 1065,   75])),
#  'RETINAL_LESIONS': (0.6574832201004028, array([  0,   1,   9, 450, 883]))}

# %%
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap
from bokeh.io import output_notebook, show

# %%
r_conversion = {k:v[1]/v[1].sum() for k, v in r.items()}

acc = {k:v[0] for k,v in r.items()}
acc
# Out:
# {'IDRID': 0.8250186443328857,
#  'MESSIDOR': 0.6515264511108398,
#  'DDR': 0.7505584359169006,
#  'FGADR': 0.7930007576942444,
#  'RETINAL_LESIONS': 0.6574832201004028}

# %%
def big_label(i):
    s = f"T={i}, ({rename(list(r_conversion.keys())[i])})"
    return s

def rename(s):
    return s.replace('RETINAL_LESIONS', 'RET-LES')

x = [big_label(i) for i in range(len(r_conversion))]


p = figure(x_range=FactorRange(*x), height=350,
           toolbar_location=None, tools="")

output_notebook()


source = ColumnDataSource(data={'x':x, 'accuracy':list(acc.values())})

p.line(x='x', y='accuracy', source=source)
p.xaxis.major_label_orientation = 1
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p12397">Loading BokehJS ...</span>
#     </div>
#   <div id="566a0b82-1599-4d35-82b4-27d97474c6f3" data-root-id="p12367" style="display: contents;"></div>

# %%
acc
# Out:
# {'IDRID': 0.8250186443328857,
#  'MESSIDOR': 0.6515264511108398,
#  'DDR': 0.7505584359169006,
#  'FGADR': 0.7930007576942444,
#  'RETINAL_LESIONS': 0.6574832201004028}

# %%
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1037">Loading BokehJS ...</span>
#     </div>
# figure(id='p1003', ...)

# %%
# Out:
# [('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'RETINAL_LESIONS')]

# %%
len(r_conversion)
# Out:
# 5

# %%
# Out:
# [('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(0)}$',
#   'RETINAL_LESIONS'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(1)}$',
#   'RETINAL_LESIONS'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(2)}$',
#   'RETINAL_LESIONS'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(3)}$',
#   'RETINAL_LESIONS'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'IDRID'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'MESSIDOR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'DDR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'FGADR'),
#  ('$\\mathcal{M}[\x08igcup_i \\mathcal{B}^{(i)}] \\looparrowright \\mathcal{B}^{(4)}$',
#   'RETINAL_LESIONS')]
